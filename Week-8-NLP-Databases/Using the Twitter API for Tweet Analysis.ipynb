# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.
#
# How do we use pickle?
# We import the package and also the os package
# to check your files.
# What does pickle do, right?
# It's a cute name for a Python utility module
# to save any Python object or data structure on disk.
# Pickle will do something special called serialization.
# To convert any Python object or in this case,
# this Twitter object, into a character stream
# so the object can be created later in Python
# when we need it.
# Reconstruction of that object is called deserialization.
# So pickle will do this for your Twitter access credentials
# and when we come back, it loads it
# back into Twitter as an object.

# %%
import pickle
import os

# %% [markdown]
# Here, let's review what's going on in this code block.
# As you see in this code block, in this if statement,
# we create an object called Twitter and we use it
# to store our access credentials.
# So consumer key, consumer secret,
# they are all stored in the Twitter object.
# If the pickled credentials exist,
# it will just load the credentials from the pickle file
# into the Twitter object.

# %%
if not os.path.exists('secret_twitter_credentials1.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials1.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials1.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in /Users/bwalsh/anaconda3/lib/python3.6/site-packages

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x107655ef0>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.
#
# Using now the trends.place from the Twitter API
# or for the Twitter API object we created
# we can get the top 50 trends for any location.
# So by default trends.place will give us the top 50 trends.

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

# top 50 trends for world, US, and local
world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %% [markdown]
# Here what we received back is a trend object
# with a response that's in JSON. We can see the response for example for world trends
# by querying the first two records.
# So here in the next code block or code cell
# we say world trends and there's a slicing range query there.
# We get back two trends.

# %%
world_trends[:2]
# Out:
# [{'as_of': '2018-02-04T17:27:07Z',
#   'created_at': '2018-02-04T17:22:26Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': '#الباطن_الهلال',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D8%A8%D8%A7%D8%B7%D9%86_%D8%A7%D9%84%D9%87%D9%84%D8%A7%D9%84',
#     'tweet_volume': 99970,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%A8%D8%A7%D8%B7%D9%86_%D8%A7%D9%84%D9%87%D9%84%D8%A7%D9%84'},
#    {'name': '#TheVoiceKids',
#     'promoted_content': None,
#     'query': '%23TheVoiceKids',
#     'tweet_volume': 140243,
#     'url': 'http://twitter.com/search?q=%23TheVoiceKids'},
#    {'name': '#SuperBowlSunday',
#     'promoted_content': None,
#     'query': '%23SuperBowlSunday',
#     'tweet_volume': 35337,
#     'url': 'http://twitter.com/search?q=%23SuperBowlSunday'},
#    {'name': 'Piqué',
#     'promoted_content': None,
#     'query': 'Piqu%C3%A9',
#     'tweet_volume': 65926,
#     'url': 'http://twitter.com/search?q=Piqu%C3%A9'},
#    {'name': '#LIVTOT',
#     'promoted_content': None,
#     'query': '%23LIVTOT',
#     'tweet_volume': 22445,
#     'url': 'http://twitter.com/search?q=%23LIVTOT'},
#    {'name': '#JanetJacksonAppreciationDay',
#     'promoted_content': None,
#     'query': '%23JanetJacksonAppreciationDay',
#     'tweet_volume': 33841,
#     'url': 'http://twitter.com/search?q=%23JanetJacksonAppreciationDay'},
#    {'name': 'HOSEOK DAY',
#     'promoted_content': None,
#     'query': '%22HOSEOK+DAY%22',
#     'tweet_volume': 1492799,
#     'url': 'http://twitter.com/search?q=%22HOSEOK+DAY%22'},
#    {'name': 'Digne',
#     'promoted_content': None,
#     'query': 'Digne',
#     'tweet_volume': 10581,
#     'url': 'http://twitter.com/search?q=Digne'},
#    {'name': 'Dier',
#     'promoted_content': None,
#     'query': 'Dier',
#     'tweet_volume': 16317,
#     'url': 'http://twitter.com/search?q=Dier'},
#    {'name': 'Emre Belözoğlu',
#     'promoted_content': None,
#     'query': '%22Emre+Bel%C3%B6zo%C4%9Flu%22',
#     'tweet_volume': 11188,
#     'url': 'http://twitter.com/search?q=%22Emre+Bel%C3%B6zo%C4%9Flu%22'},
#    {'name': '포카 105종',
#     'promoted_content': None,
#     'query': '%22%ED%8F%AC%EC%B9%B4+105%EC%A2%85%22',
#     'tweet_volume': 21865,
#     'url': 'http://twitter.com/search?q=%22%ED%8F%AC%EC%B9%B4+105%EC%A2%85%22'},
#    {'name': 'Amtrak',
#     'promoted_content': None,
#     'query': 'Amtrak',
#     'tweet_volume': 43850,
#     'url': 'http://twitter.com/search?q=Amtrak'},
#    {'name': 'Liverpool 1-0 Tottenham',
#     'promoted_content': None,
#     'query': '%22Liverpool+1-0+Tottenham%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Liverpool+1-0+Tottenham%22'},
#    {'name': 'Karius',
#     'promoted_content': None,
#     'query': 'Karius',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Karius'},
#    {'name': 'Jon Moss',
#     'promoted_content': None,
#     'query': '%22Jon+Moss%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Jon+Moss%22'},
#    {'name': 'احمد اشرف',
#     'promoted_content': None,
#     'query': '%22%D8%A7%D8%AD%D9%85%D8%AF+%D8%A7%D8%B4%D8%B1%D9%81%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22%D8%A7%D8%AD%D9%85%D8%AF+%D8%A7%D8%B4%D8%B1%D9%81%22'},
#    {'name': '#ديربي_جده',
#     'promoted_content': None,
#     'query': '%23%D8%AF%D9%8A%D8%B1%D8%A8%D9%8A_%D8%AC%D8%AF%D9%87',
#     'tweet_volume': 43205,
#     'url': 'http://twitter.com/search?q=%23%D8%AF%D9%8A%D8%B1%D8%A8%D9%8A_%D8%AC%D8%AF%D9%87'},
#    {'name': '#ITAvENG',
#     'promoted_content': None,
#     'query': '%23ITAvENG',
#     'tweet_volume': 17704,
#     'url': 'http://twitter.com/search?q=%23ITAvENG'},
#    {'name': '#OTDirecto4F',
#     'promoted_content': None,
#     'query': '%23OTDirecto4F',
#     'tweet_volume': 178019,
#     'url': 'http://twitter.com/search?q=%23OTDirecto4F'},
#    {'name': '#FelizDomingo',
#     'promoted_content': None,
#     'query': '%23FelizDomingo',
#     'tweet_volume': 30540,
#     'url': 'http://twitter.com/search?q=%23FelizDomingo'},
#    {'name': '#DiaMundialContraElCancer',
#     'promoted_content': None,
#     'query': '%23DiaMundialContraElCancer',
#     'tweet_volume': 57862,
#     'url': 'http://twitter.com/search?q=%23DiaMundialContraElCancer'},
#    {'name': '#JuveSassuolo',
#     'promoted_content': None,
#     'query': '%23JuveSassuolo',
#     'tweet_volume': 24624,
#     'url': 'http://twitter.com/search?q=%23JuveSassuolo'},
#    {'name': '#برشلونه_اسبانيول',
#     'promoted_content': None,
#     'query': '%23%D8%A8%D8%B1%D8%B4%D9%84%D9%88%D9%86%D9%87_%D8%A7%D8%B3%D8%A8%D8%A7%D9%86%D9%8A%D9%88%D9%84',
#     'tweet_volume': 23983,
#     'url': 'http://twitter.com/search?q=%23%D8%A8%D8%B1%D8%B4%D9%84%D9%88%D9%86%D9%87_%D8%A7%D8%B3%D8%A8%D8%A7%D9%86%D9%8A%D9%88%D9%84'},
#    {'name': '#DateMyFamily',
#     'promoted_content': None,
#     'query': '%23DateMyFamily',
#     'tweet_volume': 16706,
#     'url': 'http://twitter.com/search?q=%23DateMyFamily'},
#    {'name': '#بقولك_شي_بيني_وبينك',
#     'promoted_content': None,
#     'query': '%23%D8%A8%D9%82%D9%88%D9%84%D9%83_%D8%B4%D9%8A_%D8%A8%D9%8A%D9%86%D9%8A_%D9%88%D8%A8%D9%8A%D9%86%D9%83',
#     'tweet_volume': 12764,
#     'url': 'http://twitter.com/search?q=%23%D8%A8%D9%82%D9%88%D9%84%D9%83_%D8%B4%D9%8A_%D8%A8%D9%8A%D9%86%D9%8A_%D9%88%D8%A8%D9%8A%D9%86%D9%83'},
#    {'name': '#4FRebeliónDeFuturo',
#     'promoted_content': None,
#     'query': '%234FRebeli%C3%B3nDeFuturo',
#     'tweet_volume': 16362,
#     'url': 'http://twitter.com/search?q=%234FRebeli%C3%B3nDeFuturo'},
#    {'name': '#SaldırGALATASARAY',
#     'promoted_content': None,
#     'query': '%23Sald%C4%B1rGALATASARAY',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Sald%C4%B1rGALATASARAY'},
#    {'name': '#ajanac',
#     'promoted_content': None,
#     'query': '%23ajanac',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ajanac'},
#    {'name': '#حياتك1',
#     'promoted_content': None,
#     'query': '%23%D8%AD%D9%8A%D8%A7%D8%AA%D9%831',
#     'tweet_volume': 13505,
#     'url': 'http://twitter.com/search?q=%23%D8%AD%D9%8A%D8%A7%D8%AA%D9%831'},
#    {'name': '#ConsultaPopular2018',
#     'promoted_content': None,
#     'query': '%23ConsultaPopular2018',
#     'tweet_volume': 10127,
#     'url': 'http://twitter.com/search?q=%23ConsultaPopular2018'},
#    {'name': '#SMCFCN',
#     'promoted_content': None,
#     'query': '%23SMCFCN',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SMCFCN'},
#    {'name': '#UdineseMilan',
#     'promoted_content': None,
#     'query': '%23UdineseMilan',
#     'tweet_volume': 12401,
#     'url': 'http://twitter.com/search?q=%23UdineseMilan'},
#    {'name': '#الشباب_الرايد',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D8%B4%D8%A8%D8%A7%D8%A8_%D8%A7%D9%84%D8%B1%D8%A7%D9%8A%D8%AF',
#     'tweet_volume': 25412,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B4%D8%A8%D8%A7%D8%A8_%D8%A7%D9%84%D8%B1%D8%A7%D9%8A%D8%AF'},
#    {'name': '#SRFCEAG',
#     'promoted_content': None,
#     'query': '%23SRFCEAG',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SRFCEAG'},
#    {'name': '#Mesaza',
#     'promoted_content': None,
#     'query': '%23Mesaza',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Mesaza'},
#    {'name': '#domenicalive',
#     'promoted_content': None,
#     'query': '%23domenicalive',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23domenicalive'},
#    {'name': '#HappyJisungDay',
#     'promoted_content': None,
#     'query': '%23HappyJisungDay',
#     'tweet_volume': 51968,
#     'url': 'http://twitter.com/search?q=%23HappyJisungDay'},
#    {'name': '#vvvfey',
#     'promoted_content': None,
#     'query': '%23vvvfey',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23vvvfey'},
#    {'name': '#FCASGE',
#     'promoted_content': None,
#     'query': '%23FCASGE',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23FCASGE'},
#    {'name': '#CRYNEW',
#     'promoted_content': None,
#     'query': '%23CRYNEW',
#     'tweet_volume': 11392,
#     'url': 'http://twitter.com/search?q=%23CRYNEW'},
#    {'name': '#MorfiTelefe',
#     'promoted_content': None,
#     'query': '%23MorfiTelefe',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23MorfiTelefe'},
#    {'name': '#İyiHekimliğeÖzgürlük',
#     'promoted_content': None,
#     'query': '%23%C4%B0yiHekimli%C4%9Fe%C3%96zg%C3%BCrl%C3%BCk',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%C4%B0yiHekimli%C4%9Fe%C3%96zg%C3%BCrl%C3%BCk'},
#    {'name': '#ليفربول_توتنهام',
#     'promoted_content': None,
#     'query': '%23%D9%84%D9%8A%D9%81%D8%B1%D8%A8%D9%88%D9%84_%D8%AA%D9%88%D8%AA%D9%86%D9%87%D8%A7%D9%85',
#     'tweet_volume': 10667,
#     'url': 'http://twitter.com/search?q=%23%D9%84%D9%8A%D9%81%D8%B1%D8%A8%D9%88%D9%84_%D8%AA%D9%88%D8%AA%D9%86%D9%87%D8%A7%D9%85'},
#    {'name': '#EleccionesCR',
#     'promoted_content': None,
#     'query': '%23EleccionesCR',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23EleccionesCR'},
#    {'name': '#HSVH96',
#     'promoted_content': None,
#     'query': '%23HSVH96',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23HSVH96'},
#    {'name': '#Συλλαλητηριο',
#     'promoted_content': None,
#     'query': '%23%CE%A3%CF%85%CE%BB%CE%BB%CE%B1%CE%BB%CE%B7%CF%84%CE%B7%CF%81%CE%B9%CE%BF',
#     'tweet_volume': 37304,
#     'url': 'http://twitter.com/search?q=%23%CE%A3%CF%85%CE%BB%CE%BB%CE%B1%CE%BB%CE%B7%CF%84%CE%B7%CF%81%CE%B9%CE%BF'},
#    {'name': '#tubalifekazanc',
#     'promoted_content': None,
#     'query': '%23tubalifekazanc',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23tubalifekazanc'},
#    {'name': '#欅って書けない',
#     'promoted_content': None,
#     'query': '%23%E6%AC%85%E3%81%A3%E3%81%A6%E6%9B%B8%E3%81%91%E3%81%AA%E3%81%84',
#     'tweet_volume': 38913,
#     'url': 'http://twitter.com/search?q=%23%E6%AC%85%E3%81%A3%E3%81%A6%E6%9B%B8%E3%81%91%E3%81%AA%E3%81%84'},
#    {'name': '#乃木坂工事中',
#     'promoted_content': None,
#     'query': '%23%E4%B9%83%E6%9C%A8%E5%9D%82%E5%B7%A5%E4%BA%8B%E4%B8%AD',
#     'tweet_volume': 40901,
#     'url': 'http://twitter.com/search?q=%23%E4%B9%83%E6%9C%A8%E5%9D%82%E5%B7%A5%E4%BA%8B%E4%B8%AD'},
#    {'name': '#PuppyBowl',
#     'promoted_content': None,
#     'query': '%23PuppyBowl',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PuppyBowl'}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#UFCBelem', 'url': 'http://twitter.com/search?q=%23UFCBelem', 'promoted_content': None, 'query': '%23UFCBelem', 'tweet_volume': 52049}, {'name': '#NFLHonors', 'url': 'http://twitter.com/search?q=%23NFLHonors', 'promoted_content': None, 'query': '%23NFLHonors', 'tweet_volume': 94658}, {'name': 'Air Force', 'url': 'http://twitter.com/search?q=%22Air+Force%22', 'promoted_content': None, 'query': '%22Air+Force%22', 'tweet_volume': 16061}, {'name': '#SuperBowl', 'url': 'http://twitter.com/search?q=%23SuperBowl', 'promoted_content': None, 'query': '%23SuperBowl', 'tweet_volume': 181153}, {'name': '#ChicanoPark', 'url': 'http://twitter.com/search?q=%23ChicanoPark', 'promoted_content': None, 'query': '%23ChicanoPark', 'tweet_volume': None}, {'name': '#UCSD', 'url': 'http://twitter.com/search?q=%23UCSD', 'promoted_content': None, 'query': '%23UCSD', 'tweet_volume': None}, {'name': 'Amtrak', 'url': 'http://twitter.com/search?q=Amtrak', 'promoted_content': None, 'query': 'Amtrak', 'tweet_volume': 43850}, {'name': 'Katie Roiphe', 'url': 'http://twitter.com/search?q=%22Katie+Roiphe%22', 'promoted_content': None, 'query': '%22Katie+Roiphe%22', 'tweet_volume': None}, {'name': 'Reince Priebus', 'url': 'http://twitter.com/search?q=%22Reince+Priebus%22', 'promoted_content': None, 'query': '%22Reince+Priebus%22', 'tweet_volume': None}, {'name': 'Espanyol', 'url': 'http://twitter.com/search?q=Espanyol', 'promoted_content': None, 'query': 'Espanyol', 'tweet_volume': 60727}, {'name': 'Go Eagles', 'url': 'http://twitter.com/search?q=%22Go+Eagles%22', 'promoted_content': None, 'query': '%22Go+Eagles%22', 'tweet_volume': None}, {'name': 'HOSEOK DAY', 'url': 'http://twitter.com/search?q=%22HOSEOK+DAY%22', 'promoted_content': None, 'query': '%22HOSEOK+DAY%22', 'tweet_volume': 1492799}, {'name': 'Pique', 'url': 'http://twitter.com/search?q=Pique', 'promoted_content': None, 'query': 'Pique', 'tweet_volume': 65928}, {'name': 'Kam Williams', 'url': 'http://twitter.com/search?q=%22Kam+Williams%22', 'promoted_content': None, 'query': '%22Kam+Williams%22', 'tweet_volume': None}, {'name': 'Eric Dier', 'url': 'http://twitter.com/search?q=%22Eric+Dier%22', 'promoted_content': None, 'query': '%22Eric+Dier%22', 'tweet_volume': None}, {'name': 'Evan Turner', 'url': 'http://twitter.com/search?q=%22Evan+Turner%22', 'promoted_content': None, 'query': '%22Evan+Turner%22', 'tweet_volume': None}, {'name': 'Pat Robertson', 'url': 'http://twitter.com/search?q=%22Pat+Robertson%22', 'promoted_content': None, 'query': '%22Pat+Robertson%22', 'tweet_volume': 16747}, {'name': 'Harry Kane', 'url': 'http://twitter.com/search?q=%22Harry+Kane%22', 'promoted_content': None, 'query': '%22Harry+Kane%22', 'tweet_volume': None}, {'name': 'Anfield', 'url': 'http://twitter.com/search?q=Anfield', 'promoted_content': None, 'query': 'Anfield', 'tweet_volume': 20049}, {'name': 'Go Viral', 'url': 'http://twitter.com/search?q=%22Go+Viral%22', 'promoted_content': None, 'query': '%22Go+Viral%22', 'tweet_volume': None}, {'name': 'Dembele', 'url': 'http://twitter.com/search?q=Dembele', 'promoted_content': None, 'query': 'Dembele', 'tweet_volume': None}, {'name': 'Leon Panetta', 'url': 'http://twitter.com/search?q=%22Leon+Panetta%22', 'promoted_content': None, 'query': '%22Leon+Panetta%22', 'tweet_volume': None}, {'name': 'Daniel Nations', 'url': 'http://twitter.com/search?q=%22Daniel+Nations%22', 'promoted_content': None, 'query': '%22Daniel+Nations%22', 'tweet_volume': None}, {'name': 'Scot McCloughan', 'url': 'http://twitter.com/search?q=%22Scot+McCloughan%22', 'promoted_content': None, 'query': '%22Scot+McCloughan%22', 'tweet_volume': None}, {'name': 'Umtiti', 'url': 'http://twitter.com/search?q=Umtiti', 'promoted_content': None, 'query': 'Umtiti', 'tweet_volume': None}, {'name': '#LetsGoGulls', 'url': 'http://twitter.com/search?q=%23LetsGoGulls', 'promoted_content': None, 'query': '%23LetsGoGulls', 'tweet_volume': None}, {'name': '#JanetJacksonAppreciationDay', 'url': 'http://twitter.c ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %% [markdown]
# Let's import that JSON module here
# and use it in something useful.
# So in this line we are using the dumps function of JSON
# to create a better
# or more prettier version of the same output.
# Here we said the indentation format,
# we are saying indent every new parenthesis
# or every new level we would call in JSON
# with one character. We can now see thet trends.

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#SuperBowlSunday",
#     "url": "http://twitter.com/search?q=%23SuperBowlSunday",
#     "promoted_content": null,
#     "query": "%23SuperBowlSunday",
#     "tweet_volume": 35337
#    },
#    {
#     "name": "#JanetJacksonAppreciationDay",
#     "url": "http://twitter.com/search?q=%23JanetJacksonAppreciationDay",
#     "promoted_content": null,
#     "query": "%23JanetJacksonAppreciationDay",
#     "tweet_volume": 33841
#    },
#    {
#     "name": "#WorldCancerDay",
#     "url": "http://twitter.com/search?q=%23WorldCancerDay",
#     "promoted_content": null,
#     "query": "%23WorldCancerDay",
#     "tweet_volume": 156977
#    },
#    {
#     "name": "Amtrak",
#     "url": "http://twitter.com/search?q=Amtrak",
#     "promoted_content": null,
#     "query": "Amtrak",
#     "tweet_volume": 43850
#    },
#    {
#     "name": "#LIVTOT",
#     "url": "http://twitter.com/search?q=%23LIVTOT",
#     "promoted_content": null,
#     "query": "%23LIVTOT",
#     "tweet_volume": 22445
#    },
#    {
#     "name": "#KittenBowl",
#     "url": "http://twitter.com/search?q=%23KittenBowl",
#     "promoted_content": null,
#     "query": "%23KittenBowl",
#     "tweet_volume": null
#    },
#    {
#     "name": "Katie Roiphe",
#     "url": "http://twitter.com/search?q=%22Katie+Roiphe%22",
#     "promoted_content": null,
#     "query": "%22Katie+Roiphe%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Reince Priebus",
#     "url": "http://twitter.com/search?q=%22Reince+Priebus%22",
#     "promoted_content": null,
#     "query": "%22Reince+Priebus%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Espanyol",
#     "url": "http://twitter.com/search?q=Espanyol",
#     "promoted_content": null,
#     "query": "Espanyol",
#     "tweet_volume": 60727
#    },
#    {
#     "name": "Go Eagles",
#     "url": "http://twitter.com/search?q=%22Go+Eagles%22",
#     "promoted_content": null,
#     "query": "%22Go+Eagles%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "HOSEOK DAY",
#     "url": "http://twitter.com/search?q=%22HOSEOK+DAY%22",
#     "promoted_content": null,
#     "query": "%22HOSEOK+DAY%22",
#     "tweet_volume": 1492799
#    },
#    {
#     "name": "Pique",
#     "url": "http://twitter.com/search?q=Pique",
#     "promoted_content": null,
#     "query": "Pique",
#     "tweet_volume": 65928
#    },
#    {
#     "name": "Kam Williams",
#     "url": "http://twitter.com/search?q=%22Kam+Williams%22",
#     "promoted_content": null,
#     "query": "%22Kam+Williams%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Eric Dier",
#     "url": "http://twitter.com/search?q=%22Eric+Dier%22",
#     "promoted_content": null,
#     "query": "%22Eric+Dier%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Evan Turner",
#     "url": "http://twitter.com/search?q=%22Evan+Turner%22",
#     "promoted_content": null,
#     "query": "%22Evan+Turner%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Pat Robertson",
#     "url": "http://twitter.com/search?q=%22Pat+Robertson%22",
#     "promoted_content": null,
#     "query": "%22Pat+Robertson%22",
#     "tweet_volume": 16747
#    },
#    {
#     "name": "Harry Kane",
#     "url": "http://twitter.com/search?q=%22Harry+Kane%22",
#     "promoted_content": null,
#     "query": "%22Harry+Kane%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Anfield",
#     "url": "http://twitter.com/search?q=Anfield",
#     "promoted_content": null,
#     "query": "Anfield",
#     "tweet_volume": 20049
#    },
#    {
#     "name": "Go Viral",
#     "url": "http://twitter.com/search?q=%22Go+Viral%22",
#     "promoted_content": null,
#     "query": "%22Go+Viral%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Leon Panetta",
#     "url": "http://twitter.com/search?q=%22Leon+Panetta%22",
#     "promoted_content": null,
#     "query": "%22Leon+Panetta%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Daniel Nations",
#     "url": "http://twitter.com/search?q=%22Daniel+Nations%22",
#     "promoted_content": null,
#     "query": "%22Daniel+Nations%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Scot McCloughan",
#     "url": "http://twitter.com/search?q=%22Scot+McCloughan%22",
#     "promoted_content": null,
#     "query": "%22Scot+McCloughan%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Umtiti",
#     "url": "http://twitter.com/search?q=Umtiti",
#     "promoted_content": null,
#     "query": "Umtiti",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lexington County",
#     "url": "http://twitter.com/search?q=%22Lexington+County%22",
#     "promoted_content": null,
#     "query": "%22Lexington+County%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ThingsILearnedFromSports",
#     "url": "http://twitter.com/search?q=%23ThingsILearnedFromSports",
#     "promoted_content": null,
#     "query": "%23ThingsILearnedFromSports",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AMJoy",
#     "url": "http://twitter.com/search?q=%23AMJoy",
#     "promoted_content": null,
#     "query": "%23AMJoy",
#     "tweet_volume": 27107
#    },
#    {
#     "name": "#RosaParks",
#     "url": "http://twitter.com/search?q=%23RosaParks",
#     "promoted_content": null,
#     "query": "%23RosaParks",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GuacWorld",
#     "url": "http://twitter.com/search?q=%23GuacWorld",
#     "promoted_content": null,
#     "query": "%23GuacWorld",
#     "tweet_volume": 46094
#    },
#    {
#     "name": "#tphonline",
#     "url": "http://twitter.com/search?q=%23tphonline",
#     "promoted_content": null,
#     "query": "%23tphonline",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CNNSOTU",
#     "url": "http://twitter.com/search?q=%23CNNSOTU",
#     "promoted_content": null,
#     "query": "%23CNNSOTU",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SportyBaking",
#     "url": "http://twitter.com/search?q=%23SportyBaking",
#     "promoted_content": null,
#     "query": "%23SportyBaking",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ThisWeek",
#     "url": "http://twitter.com/search?q=%23ThisWeek",
#     "promoted_content": null,
#     "query": "%23ThisWeek",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HackLearning",
#     "url": "http://twitter.com/search?q=%23HackLearning",
#     "promoted_content": null,
#     "query": "%23HackLearning",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BestWayToHelpOthers",
#     "url": "http://twitter.com/search?q=%23BestWayToHelpOthers",
#     "promoted_content": null,
#     "query": "%23BestWayToHelpOthers",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BlackMenSmilling",
#     "url": "http://twitter.com/search?q=%23BlackMenSmilling",
#     "promoted_content": null,
#     "query": "%23BlackMenSmilling",
#     "tweet_volume": null
#    },
#    {
#     "name": "#cxworlds",
#     "url": "http://twitter.com/search?q=%23cxworlds",
#     "promoted_content": null,
#     "query": "%23cxworlds",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CapsKnights",
#     "url": "http://twitter.com/search?q=%23CapsKnights",
#     "promoted_content": null,
#     "query": "%23CapsKnights",
#     "tweet_volume": null
#    },
#    {
#     "name": "#4Feb",
#     "url": "http://twitter.com/search?q=%234Feb",
#     "promoted_content": null,
#     "query": "%234Feb",
#     "tweet_volume": 23624
#    },
#    {
#     "name": "#CRYNEW",
#     "url": "http://twitter.com/search?q=%23CRYNEW",
#     "promoted_content": null,
#     "query": "%23CRYNEW",
#     "tweet_volume": 11392
#    },
#    {
#     "name": "#SundayFutures",
#     "url": "http://twitter.com/search?q=%23SundayFutures",
#     "promoted_content": null,
#     "query": "%23SundayFutures",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PeopleSkills",
#     "url": "http://twitter.com/search?q=%23PeopleSkills",
#     "promoted_content": null,
#     "query": "%23PeopleSkills",
#     "tweet_volume": null
#    },
#    {
#     "name": "#THFC",
#     "url": "http://twitter.com/search?q=%23THFC",
#     "promoted_content": null,
#     "query": "%23THFC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#sundaymotivation",
#     "url": "http://twitter.com/search?q=%23sundaymotivation",
#     "promoted_content": null,
#     "query": "%23sundaymotivation",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BigGameDosOrDonts",
#     "url": "http://twitter.com/search?q=%23BigGameDosOrDonts",
#     "promoted_content": null,
#     "query": "%23BigGameDosOrDonts",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SBLll",
#     "url": "http://twitter.com/search?q=%23SBLll",
#     "promoted_content": null,
#     "query": "%23SBLll",
#     "tweet_volume": null
#    },
#    {
#     "name": "#theboyzselcaday",
#     "url": "http://twitter.com/search?q=%23theboyzselcaday",
#     "promoted_content": null,
#     "query": "%23theboyzselcaday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Juventus",
#     "url": "http://twitter.com/search?q=%23Juventus",
#     "promoted_content": null,
#     "query": "%23Juventus",
#     "tweet_volume": null
#    },
#    {
#     "name": "#KraftEntry",
#     "url": "http://twitter.com/search?q=%23KraftEntry",
#     "promoted_content": null,
#     "query": "%23KraftEntry",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NOVAvsSetonHall",
#     "url": "http://twitter.com/search?q=%23NOVAvsSetonHall",
#     "promoted_content": null,
#     "query": "%23NOVAvsSetonHall",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2018-02-04T17:27:07Z",
#   "created_at": "2018-02-04T17:22:26Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %% [markdown]
# We will keep using this JSON module in the upcoming cells
# but next let's create sets of these trends
# for each location.
# And then we'll find the commonalities between trends
# for those locations.
# So in other words
# we'll find the intersections of these sets.
# Here we are getting the name for all trends
# using a loop set trend name and for trend and world trends.
# So the first one is for world trends,
# we add that to our trend set with the world label,
# the second is for San Diego, so for US,
# and the third is third set we are creating
# is for San Diego.
# So let's run this one.

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %% [markdown]
# We have now this trends set object
# and there are three sets in it, one for the world,
# one for US, one for San Diego.
# In the next cell what we are doing is
# we are first creating a four loop
# that joins all the trends for a particular location
# and prints them in pretty format. Here we are joining trends for all three locations
# with a four loop.
# So we'll first join the trends for world, then US,
# then San Diego.
# Let's display this, the output of the cell.

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #ليفربول_توتنهام,Liverpool 1-0 Tottenham,#بقولك_شي_بيني_وبينك,#domenicalive,#乃木坂工事中,#SMCFCN,#Συλλαλητηριο,#İyiHekimliğeÖzgürlük,احمد اشرف,#HappyJisungDay,#SaldırGALATASARAY,#CRYNEW,Dier,#DateMyFamily,#tubalifekazanc,#EleccionesCR,#SuperBowlSunday,Jon Moss,#UdineseMilan,#Mesaza,#الشباب_الرايد,#LIVTOT,#برشلونه_اسبانيول,#ديربي_جده,#حياتك1,#JanetJacksonAppreciationDay,#OTDirecto4F,#SRFCEAG,#DiaMundialContraElCancer,#ConsultaPopular2018,HOSEOK DAY,#欅って書けない,#الباطن_الهلال,#vvvfey,#FCASGE,#PuppyBowl,Piqué,#MorfiTelefe,Digne,#FelizDomingo,Emre Belözoğlu,#4FRebeliónDeFuturo,#JuveSassuolo,Karius,포카 105종,#ITAvENG,#ajanac,Amtrak,#HSVH96,#TheVoiceKids
# ('----------', 'us')
# Katie Roiphe,Pique,#Juventus,Evan Turner,Kam Williams,Go Viral,#WorldCancerDay,#AMJoy,#CNNSOTU,Pat Robertson,Anfield,#GuacWorld,#KittenBowl,#CapsKnights,Harry Kane,#sundaymotivation,Espanyol,#CRYNEW,Eric Dier,#SportyBaking,#cxworlds,#KraftEntry,#SuperBowlSunday,Reince Priebus,#tphonline,#LIVTOT,#THFC,#BestWayToHelpOthers,Daniel Nations,#RosaParks,#JanetJacksonAppreciationDay,Leon Panetta,#BlackMenSmilling,#NOVAvsSetonHall,HOSEOK DAY,#theboyzselcaday,Go Eagles,Lexington County,#SundayFutures,#4Feb,#PeopleSkills,#HackLearning,#BigGameDosOrDonts,Umtiti,Amtrak,#ThisWeek,#SBLll,Scot McCloughan,#ThingsILearnedFromSports
# ('----------', 'san diego')
# Katie Roiphe,Pique,Evan Turner,#SuperBowl,Kam Williams,Go Viral,#WorldCancerDay,#ThisWeek,#AMJoy,#CNNSOTU,Pat Robertson,Anfield,#GuacWorld,#KittenBowl,#CapsKnights,Harry Kane,#UCSD,Espanyol,#CRYNEW,Eric Dier,#SportyBaking,#cxworlds,#tphonline,Reince Priebus,#LIVTOT,#THFC,#BestWayToHelpOthers,Daniel Nations,#RosaParks,#JanetJacksonAppreciationDay,#NFLHonors,Leon Panetta,#BlackMenSmilling,#SundayMorning,HOSEOK DAY,#theboyzselcaday,#UFCBelem,Dembele,#LetsGoGulls,Go Eagles,#SundayFutures,#4Feb,#PeopleSkills,#HackLearning,Umtiti,#ChicanoPark,Amtrak,Air Force,Scot McCloughan,#ThingsILearnedFromSports

# %% [markdown]
# We'll see that the world trends after a padding of 10 dashes
# and the name of our location, the location for world,
# we are printing all the elements of the trends
# for the world and for US we have a similar thing
# and for San Diego we have a similar thing,
# for all three sets.

# %% [markdown]
# Okay, now how do we create intersections
# of these texts, sets?
# We will make use of Python set objects as seen above in the cell after we imported JSON. This set object will give us an intersection function.
# So let's use that. We are saying here we are getting the set for the world
# for the topics and intersection of it for US.
# So the first one we'll give us the intersection
# of world and US, the second one will give us
# the intersection of San Diego with what's going on in US.
# Let's print these out.

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#CRYNEW', '#JanetJacksonAppreciationDay', 'HOSEOK DAY', '#SuperBowlSunday', '#LIVTOT', 'Amtrak'}
# ('==========', 'intersection of us and san-diego')
# {'Katie Roiphe', 'Pique', 'Evan Turner', 'Kam Williams', 'Go Viral', '#WorldCancerDay', '#AMJoy', '#CNNSOTU', 'Pat Robertson', 'Anfield', '#GuacWorld', '#KittenBowl', '#CapsKnights', 'Harry Kane', 'Espanyol', '#CRYNEW', 'Eric Dier', '#SportyBaking', '#cxworlds', '#tphonline', 'Reince Priebus', '#LIVTOT', '#THFC', '#BestWayToHelpOthers', 'Daniel Nations', '#RosaParks', '#JanetJacksonAppreciationDay', 'Leon Panetta', '#BlackMenSmilling', 'HOSEOK DAY', '#theboyzselcaday', 'Go Eagles', '#SundayFutures', '#4Feb', '#PeopleSkills', '#HackLearning', 'Umtiti', 'Amtrak', '#ThisWeek', 'Scot McCloughan', '#ThingsILearnedFromSports'}

# %% [markdown]
# Intersection of world and US,
# as you see it's a much smaller set.
# And here we have an intersection of San Diego and US,
# it's larger because ya know,
# US affects locally San Diego as well.
# So there we go, great.
# How about if we want to search Twitter
# for a particular topic or hashtag?
# Let's move onto the next section to find out.

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter
# <br><br>
# So there is a search that tweets under the Twitter API
# so we can search for tweets.
# And one of the arguments for it is the topic.
# And the other argument is the count of tweets we want back
# for the function to return.
# And we store that in a variable called number.
# So let's see what we get as statuses,

# %%
q = '#MTVAwards' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)
# Out:
# [{'created_at': 'Sun Feb 04 15:24:51 +0000 2018', 'id': 960172304008339457, 'id_str': '960172304008339457', 'text': 'RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! 💥…', 'truncated': False, 'entities': {'hashtags': [{'text': 'MTVAwards', 'indices': [109, 119]}], 'symbols': [], 'user_mentions': [{'screen_name': 'MTV', 'name': 'MTV', 'id': 2367911, 'id_str': '2367911', 'indices': [3, 7]}, {'screen_name': 'dylanobrien', 'name': "Dylan O'Brien", 'id': 281766200, 'id_str': '281766200', 'indices': [13, 25]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2589360386, 'id_str': '2589360386', 'name': 'hjybjy', 'screen_name': 'tenka20736', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 3, 'friends_count': 6, 'listed_count': 0, 'created_at': 'Thu Jun 26 10:48:27 +0000 2014', 'favourites_count': 2, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 536, 'lang': 'ko', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun May 07 23:02:26 +0000 2017', 'id': 861355574381789184, 'id_str': '861355574381789184', 'text': 'Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards toni… https://t.co/ocPtigIqBV', 'truncated': True, 'entities': {'hashtags': [{'text': 'MTVAwards', 'indices': [100, 110]}], 'symbols': [], 'user_mentions': [{'screen_name': 'dylanobrien', 'name': "Dylan O'Brien", 'id': 281766200, 'id_str': '281766200', 'indices': [4, 16]}], 'urls': [{'url': 'https://t.co/ocPtigIqBV', 'expanded_url': 'https://twitter.com/i/web/status/861355574381789184', 'display_url': 'twitter.com/i/web/status/8…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://snappytv.com" rel="nofollow">SnappyTV.com</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2367911, 'id_str': '2367911', 'name': 'MTV', 'screen_name': 'MTV', 'location': 'NYC', 'description': 'snapchat/musical.ly/everything: mtv | tweets by @kaitiii ✨', 'url': 'https://t.co/yyniasrs2z', 'entities': {'url': {'urls': [{'url': 'https://t.co/yyniasrs2z', 'expanded_url': 'http://mtv.com', 'display_url': 'mtv.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 15946564, 'friends_count': 32430, 'listed_count': 31099, 'created_at': 'Mon Mar 26 22:30:49 +0000 2007', 'favourites_count': 17766, 'utc_offset': -18000, 'time_zone': 'Eastern  ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:
# So because Twitter often returns
# duplicate records on a subject,
# we need to use a for loop to clean the data here
# and create a slice of the data called,
# in this case for the unique statuses,
# so we'll call that statuses.
# So what we are doing here is for each status,
# for each s,
# if the text is not in all the text,
# we are keeping all the text.
# And if the same text of the tweet,
# which is the tweet message,
# is not in already in that all_text
# that we are keeping track of,
# we are going to append that to filtered_statuses.
# And in the end when we are done with this for loop,
# we'll assign this filtered_statuses to statuses
# that object we had as the response from Twitter before.

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
len(all_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3cced6729088> in <module>()
# ----> 1 len(statuses)
#       2 # len(all_text)
#
# NameError: name 'statuses' is not defined

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! 💥…',
#  'Me pure years ago 🤣🤣🤣 #Mtvawards #ladyboss 🤣🤣🤣🤣 https://t.co/0JZB73ifg0',
#  'RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! 💥…',
#  'RT @LatinasWinning: "¡My gente latina stand up!" -  @Camila_Cabello #MTVAwards https://t.co/mIeB30c3ec',
#  'RT @BellaTwins: My 40 year old ❤ #MTVAwards https://t.co/M3MwwHaN9a',
#  'RT @EW: #HiddenFigures wins Best Fight Against the System at the #MTVAwards! https://t.co/UKX49xAMag',
#  'RT @Kabeerisgod: #MTVAwards\nStop dances and songs and pray for complete salvation\nhttps://t.co/RPLANoFnu6 https://t.co/n5cVHVBBcn',
#  '@RCARecords Thanks For Finally Putting The Proper Time &amp; Money Into @Tinashe Now @mike_nazzaro Make Sure @Tinashe P… https://t.co/F1WrsjHDus',
#  "RT @tylergposey: I'm taking over @mtv's snapchat account from the official #mtvawards + #ToyotaCHR after party. Head over to snapchat now t…",
#  'RT @BellaTwins: My 40 year old ❤ #MTVAwards https://t.co/M3MwwHaN9a',
#  'RT @lovsfriends: Sobre essa performance de bela e a fera ❤ #MTVAwards',
#  'RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! 💥…',
#  'RT @brandonflynnbr: 📷 | Fotos em HQ do Brandon no #MTVAwards https://t.co/TAjwcSrKnm',
#  'RT @xxxtristeza: ESSA MULHER E REAL?\nMARAVILHOSAA♥  #MTVAwards https://t.co/WqO4NbH1cM',
#  'RT @hsmnews: Throwback to when High School Musical 3 got 5 nominations at the 2009 #MTVAwards and won 2 of them! https://t.co/kFSUg3mzJn',
#  'RT @hsmnews: .@ZacEfron #MTVAwards https://t.co/Z1WkEyEgB9',
#  'RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! 💥…',
#  "RT @tylergposey: I'm taking over @mtv's snapchat account from the official #mtvawards + #ToyotaCHR after party. Head over to snapchat now t…",
#  'RT @KulmeetGujral: Throwback:@EmmaWatson attending the #mtvawards \nShe is so humble and kind😄😄😄😄\nShe is our Queen!💜\nAs perfect as Emma!!!!!…',
#  'RT @MTV: Thank you for your beautiful Best Actor in a Movie acceptance speech at the #MTVAwards, @EmmaWatson 💖 https://t.co/iGN3nQQylL',
#  'RT @danedehaan: Headed to the #MTVAwards!!',
#  'RT @MTV: Congrats on winning Best Host at the #MTVAwards, @Trevornoah 👏 https://t.co/INeqQWHuc9',
#  "RT @tylergposey: I'm taking over @mtv's snapchat account from the official #mtvawards + #ToyotaCHR after party. Head over to snapchat now t…",
#  '#pitbull just jumped on it like classic #topshot #MTVAWARDS',
#  'RT @_franciscompany: "El Pop Os Sienta Tan Bien" by @_franciscompany 💫👠#Cher #EltonJohn &amp; #Madonna #MTVAwards  💫  @mtvspain https://t.co/pE…',
#  "RT @tylergposey: last year I wore a onesie, this year who knows? tomorrow's the #mtvawards and I'm teaming up w/#ToyotaCHR to make some mis…",
#  'RT @billboard: .@Camila_Cabello stuns in a hot red number for her "Hey Ma" performance at the 2017 #MTVAwards https://t.co/eDpXBdqxMS',
#  'RT @billboard: Camila Cabello, Pitbull &amp; J Balvin perform "Hey Ma" at the #MTVAwards https://t.co/QhmCIsL6T9 https://t.co/4ObtAkXGWa',
#  'RT @billboard: Camila Cabello, Pitbull &amp; J Balvin perform "Hey Ma" at the #MTVAwards https://t.co/QhmCIsL6T9 https://t.co/4ObtAkXGWa',
#  'RT @billboard: .@Camila_Cabello dons a floral print minidress at the 2017  #MTVAwards https://t.co/6eZYLIAQ6R',
#  'RT @billboard: .@Camila_Cabello stuns in a hot red number for her "Hey Ma" performance at the 2017 #MTVAwards https://t.co/eDpXBdqxMS',
#  "RT @billboard: .@Camila_Cabello shares her 8 favorite films (and top TV show!) ahead of Sunday's #MTVAwards performance https://t.co/Y9kFYH…",
#  'RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! 💥…',
#  '@asoleao @SuperQPanama #Grammys no se trata de records o ventas. Son otros aspectos técnicos y musicales.… https://t.co/vvDeb3a8RG',
#  'Is there a difference between the #GRAMMYs and the #MTVAwards ceremonies nowadays? Doesn’t seem so to me.',
#  'RT @alexs_pg: #brunomarsrock  yeeeeeaaaah he is a fullfledge performer  #MTVAwards',
#  'RT @MTV: Don’t turn off the lights during this brand new clip of "IT" from the #MTVAwards airing right now! https://t.co/2rTf7HcATO',
#  'Am I watching the #Grammys2018 or #mtvawards?',
#  'RT @KulmeetGujral: Throwback:@EmmaWatson attending the #mtvawards \nShe is so humble and kind😄😄😄😄\nShe is our Queen!💜\nAs perfect as Emma!!!!!…',
#  'RT @katherinelchile: Katherine x Givenchy. #MTVAwards https://t.co/aacpiQEVA6',
#  'RT @katherinelchile: 📸 | Katherine Langford junto a Rebel Wilson  #MTVAwards https://t.co/cdwB8m7E3T',
#  'RT @KulmeetGujral: Throwback:@EmmaWatson attending the #mtvawards \nShe is so humble and kind😄😄😄😄\nShe is our Queen!💜\nAs perfect as Emma!!!!!…',
#  'RT @KulmeetGujral: Throwback:@EmmaWatson attending the #mtvawards \nShe is so humble and kind😄😄😄😄\nShe is our Queen!💜\nAs perfect as Emma!!!!!…',
#  'RT @KulmeetGujral: Throwback:@EmmaWatson attending the #mtvawards \nShe is so humble and kind😄😄😄😄\nShe is our Queen!💜\nAs perfect as Emma!!!!!…',
#  "RT @GabrielConte: We're heading to the #MTVAwards with @realisadiamond :) We loved partnering with them and can't wait for the red carpet!…",
#  'RT @KulmeetGujral: Throwback:@EmmaWatson attending the #mtvawards \nShe is so humble and kind😄😄😄😄\nShe is our Queen!💜\nAs perfect as Emma!!!!!…',
#  'RT @KulmeetGujral: Throwback:@EmmaWatson attending the #mtvawards \nShe is so humble and kind😄😄😄😄\nShe is our Queen!💜\nAs perfect as Emma!!!!!…',
#  'RT @KulmeetGujral: Throwback:@EmmaWatson attending the #mtvawards \nShe is so humble and kind😄😄😄😄\nShe is our Queen!💜\nAs perfect as Emma!!!!!…',
#  'RT @KulmeetGujral: Throwback:@EmmaWatson attending the #mtvawards \nShe is so humble and kind😄😄😄😄\nShe is our Queen!💜\nAs perfect as Emma!!!!!…',
#  'RT @KulmeetGujral: Throwback:@EmmaWatson attending the #mtvawards \nShe is so humble and kind😄😄😄😄\nShe is our Queen!💜\nAs perfect as Emma!!!!!…',
#  'Throwback:@EmmaWatson attending the #mtvawards \nShe is so humble and kind😄😄😄😄\nShe is our Queen!💜\nAs perfect as Emma… https://t.co/oZVbuNJz7Z',
#  'RT @federicodevito: Gal Gadot faz jus ao papel de Mulher-Maravilha SIM #MTVAwards https://t.co/eS5l7c8OyL',
#  'RT @MrsRare1: Bey killed this performance 🙌🙌😍😍🔥🔥 #Beyonce #Lemonade #MTVAwards https://t.co/JICNqOX9pi',
#  'RT @EmmaWatson: Thank you @MTV for a wonderful evening and thank you to everyone who voted for me! ❤️🍿 #MTVAwards @beourguest',
#  'RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! 💥…',
#  'RT @SGNewsSpain: 📸Justin Prentice  en la alfombra roja de los MTV Movie &amp; TV Awards 2017. \n#MTVAwards #SelenaBBMAs https://t.co/tRolNpe4o8',
#  'RT @SGNewsSpain: Dylan Minnette en la alfombra roja de los MTV Movie &amp; TV Awards 2017. \n#MTVAwards #SelenaBBMAs https://t.co/UYMqHRcNRY',
#  'RT @SGNewsSpain: Brandon Flynn anoche en la alfombra roja de los MTV Movie &amp; TV Awards 2017. \n#MTVAwards #SelenaBBMAs https://t.co/5yHvVpTR…',
#  'RT @SGNewsSpain: Katherine Langford y Dylan Minnette anoche en los MTV Movie &amp; TV Awards 2017. \n#MTVAwards #SelenaBBMAs https://t.co/N2BHy7…',
#  'RT @SGNewsSpain: Tommy Dorfman anoche en la alfombra roja de los MTV Movie &amp; TV Awards 2017. \n#MTVAwards #SelenaBBMAs https://t.co/9K4PaEeb…',
#  'RT @SGNewsSpain: Alisha Boe anoche en la alfombra roja de los MTV Movie &amp; TV Awards 2017. \n#MTVAwards #SelenaBBMAs https://t.co/hw7s4dW9Cf',
#  'RT @SGNewsSpain: El elenco de 13 Reasons Why anoche en la alfombra de los MTV Movie &amp; TV Awards 2017. \n#MTVAwards #SelenaBBMAs https://t.co…',
#  'RT @SGNewsSpain: El elenco femenino de 13 Reasons Why anoche en los MTV Movie &amp; TV Awards 2017. \n#MTVAwards #SelenaBBMAs https://t.co/eogWc…',
#  'RT @SGNewsSpain: El elenco de 13 Reasons Why anoche en los MTV Movie &amp; TV Awards 2017. \n#MTVAwards #SelenaBBMAs https://t.co/sflEJ5yWX3',
#  'RT @calebmclaughlin: Luke Cage is AWESOME😳💥👍🏿💥👍🏿\n#mikecolter #lukecage #marvel #mtvawards #strangerthingsSQUAD #WeWonBestTVshow #ThanksGuys…']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Sun Feb 04 15:24:51 +0000 2018",
#  "id": 960172304008339457,
#  "id_str": "960172304008339457",
#  "text": "RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! \ud83d\udca5\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "MTVAwards",
#     "indices": [
#      109,
#      119
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "MTV",
#     "name": "MTV",
#     "id": 2367911,
#     "id_str": "2367911",
#     "indices": [
#      3,
#      7
#     ]
#    },
#    {
#     "screen_name": "dylanobrien",
#     "name": "Dylan O'Brien",
#     "id": 281766200,
#     "id_str": "281766200",
#     "indices": [
#      13,
#      25
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 2589360386,
#   "id_str": "2589360386",
#   "name": "hjybjy",
#   "screen_name": "tenka20736",
#   "location": "",
#   "description": "",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 3,
#   "friends_count": 6,
#   "listed_count": 0,
#   "created_at": "Thu Jun 26 10:48:27 +0000 2014",
#   "favourites_count": 2,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 536,
#   "lang": "ko",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C0DEED",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#   "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": true,
#   "default_profile_image": true,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Sun May 07 23:02:26 +0000 2017",
#   "id": 861355574381789184,
#   "id_str": "861355574381789184",
#   "text": "Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards toni\u2026 https://t.co/ocPtigIqBV",
#   "truncated": true,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "MTVAwards",
#      "indices": [
#       100,
#       110
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "dylanobrien",
#      "name": "Dylan O'Brien",
#      "id": 281766200,
#      "id_str": "281766200",
#      "indices": [
#       4,
#       16
#      ]
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/ocPtigIqBV",
#      "expanded_url": "https://twitter.com/i/web/status/861355574381789184",
#      "display_url": "twitter.com/i/web/status/8\u2026",
#      "indices": [
#       117,
#       140
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://snappytv.com\" rel=\"nofollow\">SnappyTV.com</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 2367911,
#    "id_str": "2367911",
#    "name": "MTV",
#    "screen_name": "MTV",
#    "location": "NYC",
#    "description": "snapchat/musical.ly/everything: mtv | tweets by @kaitiii \u2728",
#    "url": "https://t.co/yyniasrs2z",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/yyniasrs2z",
#        "expanded_url": "http://mtv.com",
#        "display_url": "mtv.com",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 15946564,
#    "friends_count": 32430,
#    "listed_count": 31099,
#    "created_at": "Mon Mar 26 22:30:49 +0000 2007",
#    "favourites_count": 17766,
#    "utc_offset": -18000,
#    "time_zone": "Eastern Time (US & Canada)",
#    "geo_enabled": true,
#    "verified": true,
#    "statuses_count": 247536,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": true,
#    "profile_background_color": "131516",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#    "profile_background_tile": true,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/950404939523743749/i_YOiJ-n_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/950404939523743749/i_YOiJ-n_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/2367911/1517583226",
#    "profile_link_color": "009999",
#    "profile_sidebar_border_color": "FFFFFF",
#    "profile_sidebar_fill_color": "EFEFEF",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "regular"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 8594,
#   "favorite_count": 14079,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 8594,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
print(t['created_at'])
# Out:
# 8594
# False
# Sun Feb 04 15:24:51 +0000 2018

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %% [markdown]
# We'll use again the text screen names and hashtags
# for all these records and we'll assign them to lists.
# We'll call the first list status_texts.

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets by using split() function
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! \ud83d\udca5\u2026",
#  "Me pure years ago \ud83e\udd23\ud83e\udd23\ud83e\udd23 #Mtvawards #ladyboss \ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23 https://t.co/0JZB73ifg0",
#  "RT @LatinasWinning: \"\u00a1My gente latina stand up!\" -  @Camila_Cabello #MTVAwards https://t.co/mIeB30c3ec",
#  "RT @BellaTwins: My 40 year old \u2764 #MTVAwards https://t.co/M3MwwHaN9a",
#  "RT @EW: #HiddenFigures wins Best Fight Against the System at the #MTVAwards! https://t.co/UKX49xAMag"
# ]
# [
#  "MTV",
#  "dylanobrien",
#  "LatinasWinning",
#  "Camila_Cabello",
#  "BellaTwins"
# ]
# [
#  "MTVAwards",
#  "Mtvawards",
#  "ladyboss",
#  "MTVAwards",
#  "MTVAwards"
# ]
# [
#  "RT",
#  "@MTV:",
#  "Let",
#  "@dylanobrien",
#  "guide"
# ]

# %% [markdown]
# In the next code cell, we just the JSON dumps
# to display the first five items for each list.
# So please check out the output
# to get familiar with these lists.
# So the first one will give us the status texts
# that we just sliced out.
# The second one will give us the screen names
# that are mentioned.
# The fourth one will us the hashtags.
# And remember we searched for MTV awards
# but there are other hashtags related to these tweets as well
# so we also get those ones.
# And the last one here will give us the words
# in some of these tweets.
# Next we'll find the frequencies of these words.

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %% [markdown]
# Python offers a counter class for the purpose
# of counting the number of items in each collection.
# We will use it to count the frequencies of all
# the words in the Tweets.
# That gives us the commonly used words.
# Here we have the four item
# in words, screen names, hashtags.
# All those lists we created.
# And we are iterating
# over the counter,
# to come up with the most common words for each of them.
# So we create a counter with the item, first words,
# then screen names then hashtags.
# And we are printing them.
# For the most common 10 words.
# Let's display this.

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('RT', 39), ('#MTVAwards', 32), ('the', 21), ('&amp;', 12), ('de', 12), ('a', 10), ('Movie', 10), ('TV', 10), ('at', 9), ('and', 9)]
#
# [('SGNewsSpain', 9), ('MTV', 6), ('Camila_Cabello', 4), ('EmmaWatson', 4), ('billboard', 4), ('Tinashe', 2), ('tylergposey', 2), ('hsmnews', 2), ('_franciscompany', 2), ('katherinelchile', 2)]
#
# [('MTVAwards', 36), ('SelenaBBMAs', 9), ('mtvawards', 6), ('ToyotaCHR', 2), ('Mtvawards', 1), ('ladyboss', 1), ('HiddenFigures', 1), ('pitbull', 1), ('topshot', 1), ('MTVAWARDS', 1)]

# %% [markdown]
# So, we have definitely the RT and MTVAwards,
# the first one in the words.
# The second was for screen names,
# these are some common users,
# or Twitter screen names.
# And the MTVAwards
# and other hashtags are also represented.
# You see also here,
# MTVAwards is displayed
# a few times in different
# character settings.
# There's the upper case, lower case, combinations there.
# They are all listed separately
# because we didn't do a data cleaning. Turn the data into all caps or all lower cases.
# So they'll definitely be counted separately.
# <br><br>
# It's like a dictionary,
# by slicing it with one of the words,
# we can also check its output, for example.
# So the counter works fine.
# As you see this is the most common.
# And we just print it.
# But the output is still hard to read.
# It is a list of tuples so it has a lot of syntax
# like parenthesis
# and the rectangular parenthesis,
# square parenthesis, codes, and things like that.
# There's actually a better way to do it in Python,
# using advanced string formatting.
# And we'll use that in the next example.

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %% [markdown]
# We are using the padding option
# in advanced string formatting.
# You can format a string to a specific length
# using a format string like we do for here,
# the 20.
# It's gonna be definitely printing 20.
# And here, we have
# the left alignment
# and here we have the right alignment.
# And this is centered.
# So,
# let's go through this,
# we are creating a pretty print function.
# We specified in this if we want to center align
# or right align or things like that, that we are printing. The technical word is prettyprinting.

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# RT                   |     39
# #MTVAwards           |     32
# the                  |     21
# &amp;                |     12
# de                   |     12
# a                    |     10
# Movie                |     10
# TV                   |     10
# at                   |      9
# and                  |      9
#
#     Screen Name      | Count
# ****************************************
# SGNewsSpain          |      9
# MTV                  |      6
# Camila_Cabello       |      4
# EmmaWatson           |      4
# billboard            |      4
# Tinashe              |      2
# tylergposey          |      2
# hsmnews              |      2
# _franciscompany      |      2
# katherinelchile      |      2
#
#       Hashtag        | Count
# ****************************************
# MTVAwards            |     36
# SelenaBBMAs          |      9
# mtvawards            |      6
# ToyotaCHR            |      2
# Mtvawards            |      1
# ladyboss             |      1
# HiddenFigures        |      1
# pitbull              |      1
# topshot              |      1
# MTVAWARDS            |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#  14044  |       MTV       | RT @MTV: Don’t turn off the lights during this bra
#         |                 | nd new clip of "IT" from the #MTVAwards airing rig
#         |                 | ht now! https://t.co/2rTf7HcATO
#  8594   |       MTV       | RT @MTV: Let @dylanobrien guide you through a firs
#         |                 | t look at Maze Runner: The Death Cure, exclusively
#         |                 |  for the #MTVAwards tonight at 8/7c! 💥…
#  6389   |   EmmaWatson    | RT @EmmaWatson: Thank you @MTV for a wonderful eve
#         |                 | ning and thank you to everyone who voted for me! ❤
#         |                 | ️🍿 #MTVAwards @beourguest
#  4686   |       MTV       | RT @MTV: Thank you for your beautiful Best Actor i
#         |                 | n a Movie acceptance speech at the #MTVAwards, @Em
#         |                 | maWatson 💖 https://t.co/iGN3nQQylL
#  4129   |   tylergposey   | RT @tylergposey: last year I wore a onesie, this y
#         |                 | ear who knows? tomorrow's the #mtvawards and I'm t
#         |                 | eaming up w/#ToyotaCHR to make some mis…
#  1924   |       MTV       | RT @MTV: Congrats on winning Best Host at the #MTV
#         |                 | Awards, @Trevornoah 👏 https://t.co/INeqQWHuc9
#  1714   |   tylergposey   | RT @tylergposey: I'm taking over @mtv's snapchat a
#         |                 | ccount from the official #mtvawards + #ToyotaCHR a
#         |                 | fter party. Head over to snapchat now t…
#  1460   |    billboard    | RT @billboard: .@Camila_Cabello shares her 8 favor
#         |                 | ite films (and top TV show!) ahead of Sunday's #MT
#         |                 | VAwards performance https://t.co/Y9kFYH…
#  1332   |   BellaTwins    | RT @BellaTwins: My 40 year old ❤ #MTVAwards https:
#         |                 | //t.co/M3MwwHaN9a
#  1004   |    billboard    | RT @billboard: .@Camila_Cabello stuns in a hot red
#         |                 |  number for her "Hey Ma" performance at the 2017 #
#         |                 | MTVAwards https://t.co/eDpXBdqxMS

# %% [markdown]
# In order to get more familiar with the Twitter API,
# try to execute all of the notebook again.
# But this time, changing the location of the local trends
# to something other than San Diego.
# Maybe your own location.
# And change the hashtag in example five
# into another topic you're interested in.
# If it's a topic you're interested in,
# you'll likely find some interesting scenarios
# to analyze in that topic.
# And maybe use some of this data to do bag of words
# and identify further topics
# or sentiments related to that topic.
# Or do some other classification algorithms.
